# %%
from pathlib import Path
from course_ocr_t1.data import MidvPackage
from tqdm import tqdm
from matplotlib import pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 2
#       1 from pathlib import Path
# ----> 2 from course_ocr_t1.data import MidvPackage
#       3 from tqdm import tqdm
#       4 from matplotlib import pyplot as plt
#
# File ~/abbyy10sem/course_ocr/task1/course_ocr_t1/data.py:12
#       9 import numpy as np
#      10 from PIL import Image
# ---> 12 from .metrics import iou_relative_quads
#      15 @dataclass
#      16 class DataItem:
#      17     """
#      18     Изображение с разметкой-четырехугольником кропа.
#      19     """
#
# File ~/abbyy10sem/course_ocr/task1/course_ocr_t1/metrics.py:5
#       3 from typing import Dict
#       4 import numpy as np
# ----> 5 from shapely import geometry
#       8 def iou_relative_quads(quad1, quad2):
#       9     """
#      10     Вычисляет Intersection over Union между двумя четырехугольниками.
#      11     Четырехугольники должны быть представлены в относительном масштабе [0..1].
#      12     В вычислении IoU учитывается только площадь в пределах значений [0..1].
#      13     """
#
# ModuleNotFoundError: No module named 'shapely'

# %%
#pip install -e .
# Out:
# Obtaining file:///home/avashchilko/abbyy10sem/course_ocr/task1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from course-ocr-t1==0.1.0) (1.23.4)
# Requirement already satisfied: matplotlib in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from course-ocr-t1==0.1.0) (3.6.2)
# Collecting shapely
#   Downloading shapely-2.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 8.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cycler>=0.10 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from matplotlib->course-ocr-t1==0.1.0) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from matplotlib->course-ocr-t1==0.1.0) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from matplotlib->course-ocr-t1==0.1.0) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from matplotlib->course-ocr-t1==0.1.0) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from matplotlib->course-ocr-t1==0.1.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from matplotlib->course-ocr-t1==0.1.0) (9.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from matplotlib->course-ocr-t1==0.1.0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from matplotlib->course-ocr-t1==0.1.0) (4.38.0)
# Requirement already satisfied: six>=1.5 in /home/avashchilko/abbyy9sem/course_cvdl/.venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->course-ocr-t1==0.1.0) (1.16.0)
# Installing collected packages: shapely, course-ocr-t1
#   Running setup.py develop for course-ocr-t1
# Successfully installed course-ocr-t1-0.1.0 shapely-2.0.1
#
# [notice] A new release of pip available: 22.2 -> 23.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
DATASET_PATH = Path() / '..' / '..'/ '..' / 'data' / 'midv500_compressed'
assert DATASET_PATH.exists(), DATASET_PATH.absolute()

# %%
# Собираем список пакетов (MidvPackage) 
data_packs = MidvPackage.read_midv500_dataset(DATASET_PATH)
len(data_packs), type(data_packs[0])
# Out:
# (50, course_ocr_t1.data.MidvPackage)

# %%
# В каждом пакете - 300 штук DataItem
dp = data_packs[0]
di = dp[220]
type(dp), len(dp), type(di)
# Out:
# (course_ocr_t1.data.MidvPackage, 300, course_ocr_t1.data.DataItem)

# %%
# DataItem содержит пути до файлов изображения и разметки
di.gt_path, di.img_path
# Out:
# (WindowsPath('../../../data/midv500_compressed/01_alb_id/ground_truth/PS/PS01_11.json'),
#  WindowsPath('../../../data/midv500_compressed/01_alb_id/images/PS/PS01_11.png'))

# %%
# в gt_data (данные json) quad в абсолютных значениях (пиксели)
np.array(di.gt_data['quad'])
# Out:
# array([[220, 299],
#        [598, 315],
#        [626, 571],
#        [202, 541]])

# %%
# Можно посмотреть изображения и разметку; в .quadrangle используются относительные единицы
print(di.quadrangle)
di.image
# Out:
# [[0.48888889 0.37375   ]
#  [1.32888889 0.39375   ]
#  [1.39111111 0.71375   ]
#  [0.44888889 0.67625   ]]
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=450x800 at 0x294313E5FD0>

# %%
# Можно отрисовать разметку
# Не обязательно весь документ виден в кадре
di.show()

# %%
# DataItem содержит в себе информацию, относится ли он к test_split и целиком ли разметка внутри кадра
di.is_test_split(), di.is_quad_inside()
# Out:
# (False, False)

# %%
print(data_packs[38][238].is_test_split())
data_packs[38][238].show()
# Out:
# True

# %%
## Статистика, как часто разметка не целиком в кадре
is_quad_inside = []
for dp in tqdm(data_packs):
    for i in range(len(dp)):
        is_quad_inside.append(dp[i].is_quad_inside())
is_quad_inside = np.array(is_quad_inside).astype(int)
print(f"В {is_quad_inside.sum()} из {len(is_quad_inside)} случаев разметка кропа(т.е. документ) целиком в кадре")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [02:18<00:00,  2.77s/it]
# В 9992 из 15000 случаев разметка кропа(т.е. документ) целиком в кадре

# %%
## Статистика test-split
is_test_split = []
for dp in tqdm(data_packs):
    for i in range(len(dp)):
        is_test_split.append(dp[i].is_test_split())
is_test_split = np.array(is_test_split).astype(int)
print(f"В {is_test_split.sum()} из {len(is_test_split)} случаев кадр принадлежит к test-split")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 62.34it/s]
# В 4250 из 15000 случаев кадр принадлежит к test-split

# %% [markdown]
# ## Classic CV baseline

# %% [markdown]
# ### Для работы baseline нужен установленныей OpenCV

# %%
import cv2

# %%
class SimpleBaselineCrop:
    """
    Baseline на основе поиска и сопоставления ключевых точек на шаблоне(ref) и запросе(query)
    Алгоритм:
        0. Найти ключевые точки(КТ) на ref
        1. Найти ключевые точки(КТ) на query
        2. Сопоставить КТ query и ref друг-другу
        3. На основе сопоставления найти гомографию из ref в query
        4. Отобразить 4 угла изображения ref в query - это искомый четырехугольник кропа
    """
    def __init__(self, ref_image):
        self.ref_image = ref_image
        
        # 0. Найти ключевые точки(КТ) на ref
        self.ref_kpts, self.ref_fts = self.compute_kps(
            self.ref_image
        )

    def compute_kps(self, img, response_quantile=0.25):
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        sift = cv2.SIFT_create()
        kp = sift.detect(gray, None)
        # фильтруем 25% неуверенных точек
        q_val = np.quantile(list(k.response for k in kp), response_quantile)
        kp = [k for k in kp if k.response > q_val]
        
        kp, features = sift.compute(gray, kp)
        return kp, features 
    
    def find_qr_homography(self, kp_q, ft_q, kp_r, ft_r, ratio=0.75):
        # 2. Сопоставить КТ query и ref друг-другу
        bf = cv2.BFMatcher()
        matches = bf.knnMatch(ft_q, ft_r, k=2)
        good = []

        # Дополнителный опциональный шаг - фильтрация Lowe, Lowe ratio-test:
        # Пусть есть лучший матч1 (query-kp, ref-kp)
        # Если есть другой возможный матч2 (query-kp, ref-kp2), и их качество
        # (т.е. расстояние в пространстве features) маленькое,
        # то нельзя быть уверенном, что матч1 - надежный, и проще его выбросить
        for m,n in matches:
            if m.distance <  ratio * n.distance:
                good.append([m])
                
        ptsA = np.zeros((len(good), 2), dtype="float")
        ptsB = np.zeros((len(good), 2), dtype="float")

        for (i, mlist) in enumerate(good):
            m = mlist[0]
            ptsA[i] = kp_q[m.queryIdx].pt
            ptsB[i] = kp_r[m.trainIdx].pt
        # 3. На основе сопоставления найти гомографию из ref в query
        (H, mask) = cv2.findHomography(ptsB, ptsA, method=cv2.RANSAC)
        return H
              
    def compute_crop(self, ref_img, hmg):
        # 4. Отобразить 4 угла изображения ref в query - это искомый четырехугольник кропа
        h, w, _ = ref_img.shape
        h = float(h)
        w = float(w)
        points = [
            [0, 0],
            [w, 0],
            [w, h],
            [0, h],
        ]
        points_crop = []
        for p in points:
            # применяем гомографию к точке, представленной в гомогенных координатах
            vec = hmg @ np.array([p[0], p[1], 1])
            points_crop.append([vec[0]/vec[-1], vec[1]/vec[-1]])
        return np.array(points_crop)
        
    def __call__(self, query_image):
        # 1. Найти ключевые точки(КТ) на query
        kpts, fts = self.compute_kps(query_image)
        
        homography = self.find_qr_homography(
            kpts, fts, self.ref_kpts, self.ref_fts
        )
        abs_crop = self.compute_crop(self.ref_image, homography)
        h, w, _ = query_image.shape
        rel_crop = abs_crop / np.array([[w, h]])
        return rel_crop

# %%
bcm = SimpleBaselineCrop(np.array(dp.template_item.image))

# %%
pred_quad = bcm(np.array(dp[0].image))

# %%
pred_quad, dp[0].quadrangle
# Out:
# (array([[0.0570968 , 0.47387   ],
#         [0.73702367, 0.33407344],
#         [0.92789712, 0.56707864],
#         [0.22790701, 0.72985275]]),
#  array([[0.05555556, 0.47375   ],
#         [0.73555556, 0.335     ],
#         [0.92666667, 0.5675    ],
#         [0.22666667, 0.72875   ]]))

# %%
dp[0].show(pred_quad)

# %%
results_dict = dict()

for dp in tqdm(data_packs):
    bcm = SimpleBaselineCrop(np.array(dp.template_item.image))
    for i in range(len(dp)):
        if dp[i].is_test_split():
            try:
                results_dict[dp[i].unique_key] = bcm(np.array(dp[i].image))
            except Exception as exc:
                # Для пропущенных в словаре ключей в метриках автоаматически засчитается IoU=0
                print(exc)
# Out:
#  18%|██████████████▉                                                                    | 9/50 [00:44<03:21,  4.93s/it]
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  22%|██████████████████                                                                | 11/50 [00:54<03:10,  4.89s/it]
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  42%|██████████████████████████████████▍                                               | 21/50 [01:47<02:30,  5.20s/it]
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  74%|████████████████████████████████████████████████████████████▋                     | 37/50 [03:07<01:03,  4.89s/it]
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  86%|██████████████████████████████████████████████████████████████████████▌           | 43/50 [03:36<00:33,  4.83s/it]
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  88%|████████████████████████████████████████████████████████████████████████▏         | 44/50 [04:04<01:10, 11.79s/it]
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  92%|███████████████████████████████████████████████████████████████████████████▍      | 46/50 [05:08<01:27, 21.86s/it]
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  94%|█████████████████████████████████████████████████████████████████████████████     | 47/50 [05:38<01:13, 24.39s/it]
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
#  96%|██████████████████████████████████████████████████████████████████████████████▋   | 48/50 [06:10<00:53, 26.68s/it]
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  98%|████████████████████████████████████████████████████████████████████████████████▎ | 49/50 [06:40<00:27, 27.82s/it]
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [07:09<00:00,  8.58s/it]

# %% [markdown]
# ### Сохраним результаты и измерим точность
# Результаты - словарь с ключем DataItem.unique_key() и значением предсказанным quadrangle в относительных единицах.

# %%
from course_ocr_t1.metrics import dump_results_dict, measure_crop_accuracy

# %%
dump_results_dict(results_dict, Path() / 'pred.json')

# %%
acc = measure_crop_accuracy(
    Path() / 'pred.json',
    Path() / 'gt.json'
)
# Out:
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.21753268826645977 0.3983220189884889
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.24267092641131427 1.0036751396197334
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.2489398749962479 0.61840575187455327
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.44348531834108612 0.17502315660701648
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.31785719979850807 0.35344790187057251
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.2858160578946452 0.7924760927577722
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.32639011021065356 0.44477990439045184
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.59905007499613883 0.51516165350602616
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.43343395669139045 0.40586596966807603
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.59851932714406531 0.34480068964905869
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.92432446513463806 0.0020031481810836521
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.40719908169922375 0.73372487966082844
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.67885022483975821 0.80127090470025641
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.81040346005406594 0.8157808044482312
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.66358583280249284 0.80467434096641999
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.53548133909594875 0.84584234525944668
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.070017875784592426 0.86928861944340374
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.65174913009876234 0.71413168746259648
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.50841890229141395 0.99774805366027042
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.63420598077968537 0.91141613132351573
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.25750051792642475 0.93367382508714913
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.45323577381982416 0.99198320085196001
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.051838073254417139 1.0494829655609226
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.76309716854811671 0.24178548126435373
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.42738779476885169 0.26595102183302799
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.66790045147276345 0.40240446770694738
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.68134676146492079 0.32442415202060154
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.36956671086044335 0.34374855867439447
# TopologyException: Input geom 1 is invalid: Self-intersection at 0.59544564056679572 0.60332435342418456
# TopologyException: Input geom 0 is invalid: Self-intersection at 0.25778359902297987 0.31700696285527624
# TopologyException: Input geom 0 is invalid: Self-intersection at 1.1175935956246565 0.79161166433033603

# %%
print("Точность кропа: {:1.4f}".format(acc))
# Out:
# Точность кропа: 0.9609
